# %% [markdown]
# <a href="https://colab.research.google.com/github/Ps1012/Data-science-/blob/main/eda_prabhjot_singh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
male=df[df["sex"]=="male"]["sex"].count()
female=df[df["sex"]=="female"]["sex"].count()
print("no. of male:",male)
print("no. of female:",female)
# Out:
# no. of male: 676
# no. of female: 662

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
smoker=df[df["smoker"]=="yes"]["smoker"].count()
non_smoker=df[df["smoker"]=="no"]["smoker"].count()
print("no. of smokers:",smoker)
print("no. of non smokers:",non_smoker)
# Out:
# no. of smokers: 274
# no. of non smokers: 1064

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
south_west=df[df["region"]=="southwest"]["region"].count()
north_west=df[df["region"]=="northwest"]["region"].count()
south_east=df[df["region"]=="southeast"]["region"].count()
north_east=df[df["region"]=="northeast"]["region"].count()
print("south west:",south_west)
print("north west:",north_west)
print("south east:",south_east)
print("north east:",north_east)
# Out:
# south west: 325
# north west: 325
# south east: 364
# north east: 324

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
smoker=df[df["smoker"]=="yes"]
non_smoker=df[df["smoker"]=="no"]
male_smoker=smoker[smoker["sex"]=="male"]["sex"].count()
male_non_smoker=non_smoker[non_smoker["sex"]=="male"]["sex"].count()
female_smoker=smoker[smoker["sex"]=="female"]["sex"].count()
female_non_smoker=non_smoker[non_smoker["sex"]=="female"]["sex"].count()
print("no. of male smoker:",male_smoker)
print("no. of male non smoker:",male_non_smoker)
print("no. of female smoker:",female_smoker)
print("no. of female non smoker:",female_non_smoker)
# Out:
# no. of male smoker: 159
# no. of male non smoker: 517
# no. of female smoker: 115
# no. of female non smoker: 547

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.shape
# Out:
# (1338, 7)

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=[676,662]
y=["Male","FeMale"]
plt.pie(x,labels=y,autopct="%2.1f%%",explode=[0.1,0],shadow=True)
plt.legend(title="GENDER DISTRIBUTION")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=[274,1064]
y=["Smoker","Non Smoker "]
plt.pie(x,labels=y,autopct="%2.1f%%",explode=[0.1,0],shadow=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=[325,325,364,324]
y=["south west","north west","south east","north east"]
plt.pie(x,labels=y,autopct="%2.1f%%",explode=[0.1,0.1,0.1,0.1],shadow=True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("insurance.csv")
sns.countplot(x="region",data=df,hue="sex")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("insurance.csv")
sns.displot(df["charges"],kde=True,rug=True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("insurance.csv")
sns.countplot(x="children",data=df,hue="sex")
plt.savefig("children.png")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("insurance.csv")
fg=sns.FacetGrid(df,col="region")
fg.map(plt.bar,"age","charges").add_legend()
plt.show()

# %% [markdown]
# Average charges

# %%
average=df["charges"].mean()
print("average charges are:",average)
# Out:
# average charges are: 13270.422265141257

# %%
sns.displot(df["bmi"],kde=True)
plt.show()
